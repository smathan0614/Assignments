# %% [markdown]
# Python Objective Solution

# %% [markdown]
# 1. b
# 2. b
# 3. b
# 4. d
# 5. d
# 6. c
# 7. d
# 8. b
# 9. D
# 10. b
# 11. c - a=20
# 12. a
# 13. c
# 14. b
# 15. b
# 16. c
# 17. b
# 18. d
# 19. b
# 20. c
# 21. b
# 22. b
# 23. a
# 24. c
# 25. a
# 26. c
# 27. b
# 28. c
# 29. b
# 30. d
# 31. b
# 32. b
# 33. b
# 34. b
# 35. c
# 36. a
# 37. c
# 38. a
# 39. b
# 40. c
# 41. a
# 42. a
# 43. c
# 44. d
# 45. c
# 46. b
# 47. a
# 48. a
# 49. c
# 50. c
# 51. a
# 52. b
# 53. b
# 54. c
# 55. c
# 56. a
# 57. b,c
# 58. /animals/feline/
# 59. open('jack_russell.png', 'rb')
# 	open('jack_russell.png', bytes=True)
# 60. /animals/ursine/bears.gif
# 61. a
# 62. /animals/ursine/bears.gif
# 63. b
# 64. a
# 65. a
# 66. B
# 67. A
# 68. D
# 69. A
# 70. a
# 71. c
# 72. d
# 73. c
# 74. d
# 75. b
# 76. a
# 77. a
# 78. d
# 79. B
# 80. a
# 81. c
# 82. a
# 83. a
# 84. d
# 85. d
# 86. a
# 87. B
# 88. d
# 89. c
# 90. c
# 91. b
# 92. c
# 93. d
# 94. d
# 95. b
# 96. d
# 97. c
# 98. c
# 99. b
# 100. a
# 101. c
# 102. a
# 103. a
# 104. d
# 105. b
# 106. a
# 107. a
# 108. b
# 109. a
# 110. d
# 111. c
# 112. b
# 113. a
# 114. b
# 115. c
# 116. b
# 117. b
# 118. c
# 119. a
# 120. a
# 120. A
# 121. C
# 122. D
# 123. A
# 124. A
# 125. C
# 126. A
# 127. B
# 128. C
# 129. A
# 130. A
# 131. A
# 132. A
# 133. A
# 134. A
# 135. C
# 136. B
# 137. B
# 138. A
# 139. B
# 140. A
# 141. B
# 142. D
# 143. D
# 144. A
# 145. A
# 146. A
# 147. B
# 148. A
# 149. B
# 150. A
